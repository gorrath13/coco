# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_prase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
if long_phrase > short_prase:
    print('yes')
# Out:
# yes

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
a=213682424
b=a/1024
print(round(b,2), ' Mb')
# Out:
# 208674.24  Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
day = input('Введи день рождения ')
day = int(day)
month = input('Введи месяц родждения ')
month = int(month)
if month == 1 and day<=32:
    print('Январский зодиак')
elif month == 2 and day<=32:
    print('Февральский зодиак')
elif month == 3 and day<=29:
    print('Мартовский зодиак')
elif month == 4 and day<=32:
    print('Апрельский зодиак')
elif month == 5 and day<=32:
    print('Майский зодиак')
elif month == 6 and day<=32:
    print('Июньский зодиак')
elif month == 7 and day<=32:
    print('Июльский зодиак')
elif month == 8 and day<=32:
    print('Августовский зодиак')
elif month == 9 and day<=32:
    print('Сентябрьский зодиак')
elif month == 10 and day<=32:
    print('Октябрьский зодиак')
elif month == 11 and day<=32:
    print('Ноябрьский зодиак')
elif month == 12 and day<=32:
    print('Декабрьский зодиак')
else: print ('Проверь ввод плес')
# Out:
# Введи день рождения 1
# Введи месяц родждения 2
# Февральский зодиак

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
Pay = int(input('Введите заработанную плату в месяц ')) 
Ipot_Payment = int(input('Введите сколько процентов уходит на ипотеку ')) 
Perc_Life = int(input('Введите сколько процентов уходит на жизнь ')) 
Prem_pay = int(input('Введите количество премий за год ')) 
print('На ипотеку потрачено: ')
print(Pay*Ipot_Payment/100*12) 
print('На житуху накоплено: ')
print(Pay*12-Pay*Perc_Life/100*12-Pay*Ipot_Payment/100*12+Prem_pay*Pay)
# Out:
# Введите заработанную плату в месяц 13
# Введите сколько процентов уходит на ипотеку 1
# Введите сколько процентов уходит на жизнь 3
# Введите количество премий за год 1
# На ипотеку потрачено:
# 1.56
# На житуху накоплено:
# 162.76
